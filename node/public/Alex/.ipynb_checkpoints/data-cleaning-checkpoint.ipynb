# %% [markdown]
# # Cleaning Song Data for D3.js

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

# %%
spot_df = pd.read_csv('../data/Spotify Dataset.csv')

# %%
spot_df
# Out:
#       index          artist                                    song  \
# 0         0  Britney Spears                  Oops!...I Did It Again
# 1         1       blink-182                    All The Small Things
# 2         2      Faith Hill                                 Breathe
# 3         3        Bon Jovi                            It's My Life
# 4         4          *NSYNC                             Bye Bye Bye
# ...     ...             ...                                     ...
# 1973   1995  Jonas Brothers                                  Sucker
# 1974   1996    Taylor Swift                            Cruel Summer
# 1975   1997    Blanco Brown                              The Git Up
# 1976   1998       Sam Smith  Dancing With A Stranger (with Normani)
# 1977   1999     Post Malone                                 Circles
#
#       duration_ms  explicit  year  popularity  danceability  energy  key  \
# 0          211160     False  2000          77         0.751   0.834    1
# ...

# %% [markdown]
# ## Importing Data

# %%
df = pd.read_csv('../data/songs_normalize.csv')
df
# Out:
#               artist                                    song  duration_ms  \
# 0     Britney Spears                  Oops!...I Did It Again       211160
# 1          blink-182                    All The Small Things       167066
# 2         Faith Hill                                 Breathe       250546
# 3           Bon Jovi                            It's My Life       224493
# 4             *NSYNC                             Bye Bye Bye       200560
# ...              ...                                     ...          ...
# 1995  Jonas Brothers                                  Sucker       181026
# 1996    Taylor Swift                            Cruel Summer       178426
# 1997    Blanco Brown                              The Git Up       200593
# 1998       Sam Smith  Dancing With A Stranger (with Normani)       171029
# 1999     Post Malone                                 Circles       215280
#
#       explicit  year  popularity  danceability  energy  key  loudness  mode  \
# ...

# %% [markdown]
# Grouping by year and averaging everything else

# %%
year_df = df.groupby('year').mean()

# %%
year_df.to_csv('../data/grouped-by-year.csv')

# %% [markdown]
# # New file - Removing Strings

# %%
df
# Out:
#               artist                                    song  duration_ms  \
# 0     Britney Spears                  Oops!...I Did It Again       211160
# 1          blink-182                    All The Small Things       167066
# 2         Faith Hill                                 Breathe       250546
# 3           Bon Jovi                            It's My Life       224493
# 4             *NSYNC                             Bye Bye Bye       200560
# ...              ...                                     ...          ...
# 1995  Jonas Brothers                                  Sucker       181026
# 1996    Taylor Swift                            Cruel Summer       178426
# 1997    Blanco Brown                              The Git Up       200593
# 1998       Sam Smith  Dancing With A Stranger (with Normani)       171029
# 1999     Post Malone                                 Circles       215280
#
#       explicit  year  popularity  danceability  energy  key  loudness  mode  \
# ...

# %%
star_df = df.drop(['song', 'explicit', 'artist', 'genre', 'mode'], axis=1)
#star_df.rename(columns={ df.columns[0]: "index" }, inplace = True)
star_df.to_csv('../data/removed-strings.csv')

# %%
df.columns
# Out:
# Index(['artist', 'song', 'duration_ms', 'explicit', 'year', 'popularity',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'genre'],
#       dtype='object')
